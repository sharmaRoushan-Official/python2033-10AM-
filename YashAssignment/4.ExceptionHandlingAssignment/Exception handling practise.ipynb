# %%
#1. Write a program that takes two integers as input and handles division by zero using try and except.
try:
    a=int(input("Enter first number :"))
    b=int(input("Enter second number :"))
    print(a/b)
except ZeroDivisionError:
    print("Error Occured(ZeroDivisionError)")
# Out:
# Enter first number : 12
# Enter second number : 0
# Error Occured(ZeroDivisionError)

# %%
#2. Write a program that reads an integer from the user and handles invalid input using exception handling.
try:
    a=int(input("Enter the number :"))
    print(f"Entered Integer is {a}")
except ValueError:
    print(f"ValueError occured\n Please enter correct value")
else:
    print("Exceution successful")
# Out:
# Enter the number : s
# ValueError occured
#  Please enter correct value

# %%
#3. Write a program to access an element in a list using an index entered by the user and handle IndexError.
try:
   list1= ['Python',3.14,2002,True,False,[11,1,1,2,3,50.66,-1],('hello',"World"),{1,1,2,3,5},{'a':'apple',"b":'boy'}]
   index=int(input("Enter the index number :"))
   print(f"The Entered index number is {index}\n And Element is {list1[index]}") 
    
except IndexError:
    print("IndexError")
except ValueError:
    print("ValueError")
else:
    print("Exceution successful")
# Out:
# Enter the index number : h
# ValueError

# %%
#4. Write a program that opens a file named data.txt and handles the case when the file does not exist
try:
    file=open("data.txt","r")
    reading=file.read()
    print(reading)
    file.close()
except FileNotFoundError:
    print(f"FileNotFoundError is Occured\n Means File not exists")
# Out:
# FileNotFoundError is Occured
#  Means File not exists

# %%
#5. Write a program that converts a string to an integer and handles possible exceptions.
try:
    stri=int(input("enter the string :"))
    print(stri)
except ValueError:
    print("Value Error Occurred")
except TypeError:
    print("Type Error Occurred")
else:
    print("Exceution successful")
# Out:
# enter the string : 14
# 14
# Exceution successful

# %%
try:
    stri=input("enter the string :")
    #num=stri
    num=int(stri)
    print(num)
except ValueError:
    print("Value Error Occurred")
except TypeError:
    print("Type Error Occurred")
else:
    print("Exceution successful")
# Out:
# enter the string : ab
# Value Error Occurred

# %%
#6. Write a program to perform multiple arithmetic operations and catch any runtime errors.
try:
    num1 = float(input("Enter Number"))
    num3 = input("Enter Operator")
    num2 = float(input("Enter Number"))
    
    
    
    if num3 == "+" :
        outp=num1 + num2
        print(f"The Sum of Two Number is {outp}")
    elif num3 == "-" :
        outp1=num1 - num2
        print(f"The Subtraction of Two Number is {outp1}")
    elif num3 == "*" :
        outp2=num1 * num2
        print(f"The Multiplication of Two Number is {outp2}")
    elif num3 == "/" :
        outp3=num1 / num2
        print(f"The Divison of Two Number is {outp3}")
    else :
        print(f"Enter Operator Properly")
except Exception as e:
    print(f"Error occured - {e} ")
# Out:
# Enter Number 8
# Enter Operator -
# Enter Number o
# Error occured - could not convert string to float: 'o'

# %%
#7. Write a program that uses try and except to handle a KeyError when accessing a dictionary
try:
    dict1 = {
    "id":"101",
    'name':"Yash Meshram",
    "age":25,
    "contact_Address":"Pune"}
    enter=input("Enter Key element :")
    print(f"The value of '{enter}' is: {dict1[enter]}")
except KeyError:
    print(f"Error occurred: Key does not exist in dictionary.")
# Out:
# Enter Key element : kjl
# Error occurred: Key does not exist in dictionary.

# %%
#8. Write a program that demonstrates the use of multiple except blocks for different exceptions.
try:
    a=int(input("Enter first number :"))
    b=int(input("Enter second number :"))
    print(a/b)
except ZeroDivisionError:
    print(f"Error occurred: ZeroDivisionError ")
except ValueError:
    print(f"Error occured : ValueError")
except Exception as e:
    print("Unexpected error:", e)  
else:
    print("Execution is sucessful")
# Out:
# Enter first number : 14
# Enter second number : 2
# 7.0
# Execution is sucessful

# %%
#9.  Write a program that uses the else block to print a message if no exception occurs.


try:
    a=int(input("Enter first number :"))
    b=int(input("Enter second number :"))
    print(a/b)
except ZeroDivisionError:
    print(f"Error occurred: ZeroDivisionError ")
except ValueError:
    print(f"Error occured : ValueError")
except Exception as e:
    print("Unexpected error:", e)  
else:
    print("Execution is sucessful")
# Out:
# Enter first number : 5
# Enter second number : 5
# 1.0
# Execution is sucessful

# %%
#10. Write a program that uses the finally block to close a file after reading data.
try:
    file=open("C:\\Users\\Yash\\OneDrive\\Desktop\\Tirupati.txt","r")
    reading=file.read()
    print(reading)
   
except FileNotFoundError:
    print(f"FileNotFoundError is Occured\n Means File not exists")
else:
    print("Execution is sucessful")
finally:
    print("File closed successfully")
# Out:
# Yash Surendra Meshram  25M 817066361347 yashmeshram6174@gmail.com
# Archana Surendra Meshram 49F 256037617850
# Parshuram Pandurang Gurav 53M 553497946399
# Kalpana Parshuram Gurav 53F 564150730003
# Omkar Parshuram Gurav 26M   663100589633
# Palak Virendra Agarwal 14F  929674496452
#
# Execution is sucessful
# File closed successfully

# %%
#11. Write a program that takes user input for a filename and safely reads its contents using exception handling.
try:
    enter=input("Enter File Name :")
    file=open(enter,"r")
    reading=file.read()
    print(reading)
    file.close()
except FileNotFoundError:
    print(f"FileNotFoundError is Occured\n Means File not exists")
else:
    print("Execution is sucessful")
# Out:
# Enter File Name : C:\Users\Yash\OneDrive\Desktop\Tirupati.txt
# Yash Surendra Meshram  25M 817066361347 yashmeshram6174@gmail.com
# Archana Surendra Meshram 49F 256037617850
# Parshuram Pandurang Gurav 53M 553497946399
# Kalpana Parshuram Gurav 53F 564150730003
# Omkar Parshuram Gurav 26M   663100589633
# Palak Virendra Agarwal 14F  929674496452
#
# Execution is sucessful

# %%
#12. Write a program that handles both ValueError and ZeroDivisionError in a single try block
try:
    a=int(input("Enter first number :"))
    b=int(input("Enter second number :"))
    print(a/b)
except (ZeroDivisionError, ValueError):
    print("Error")
# Out:
# Enter first number : 14
# Enter second number : 0
# Error

# %%
#13. Write a program that raises a custom exception when a negative number is entered.

a=int(input("Enter  number :"))
if a<0:
   raise ValueError("Number Must be 0 or above")
print("The Entered Number is Non-negtive")
# Out:
# Enter  number : 9
# The Entered Number is Non-negtive

# %%
#14 .Write a program that uses try-except-finally to demonstrate cleanup code execution.
try:
    file=open("C:\\Users\\Yash\\OneDrive\\Desktop\\Tirupati.txt","r")
    reading=file.read()
    print(reading)
   
except FileNotFoundError:
    print(f"FileNotFoundError is Occured\n Means File not exists")
else:
    print("Execution is sucessful")
finally:
    print("File closed successfully")

# %%
#15. Write a program that handles an exception while parsing a floating-point number.
try:
    floatnum=str(input("Enter  number :"))
    num=float(floatnum)
    print(floatnum)
except Exception as e:
    print(e)
# Out:
# Enter  number : 14.2
# 14.2

# %%
try:
    str1=str(input("enter the string:"))
    num=int(str1)
    print(num)
except Exception as a:
    print(a)
# Out:
# enter the string: 14
# 14

# %%
#16. Write a program that catches a TypeError when adding incompatible data types.
try:
    a=input("Enter data :")
    b=input("Enter data :")
    sumo=a+b
    print(sumo)
except TypeError:
    print("TypeError")
# Out:
# Enter data : 14
# Enter data : jj
# 14jj

# %%
try:
    a=str(input("Enter data :"))
    b=input("Enter data :")
    sumo=a+b 
   # result = '10' + 5
    #print(result)
except TypeError:
    print("Cannot add string and integer")
# Out:
# Cannot add string and integer

# %%
#write a program take username print total numbers of characters ,vowels and consonent.
try:
    def countcvc():
        username=input("Enter Any Name :").lower()
        vowels="aeiou"
        vowlist = []
        conslist = []
        countvowels=0
        countcons=0
        for i in username:
          if i.isalpha():
            if i in vowels:
                countvowels+=1
                vowlist.append(i)
            else:
                countcons+=1
                conslist.append(i)
        print("List of Vowels",vowlist,"is",countvowels) 
        print("List of consonant",conslist,"is",countcons) 
        print("List of characters",len(username)) 
    countcvc()
except ValueError:
    print("value error")
# Out:
# Enter Any Name : jhg4
# List of Vowels [] is 0
# List of consonant ['j', 'h', 'g'] is 3
# List of characters 4

# %%
#17.  Write a program that demonstrates nested try-except blocks.
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    try:
        result = num1 / num2
        print("Result:", result)

    except ZeroDivisionError:
        print("Zerodivisionerror: Cannot divide by zero!")

except ValueError:
    print("value error: Please enter valid integers!")

else:
    print("Program executed successfully!")

finally:
    print("Execution completed.")
# Out:
# Enter first number:  k
# value error: Please enter valid integers!
# Execution completed.

# %%
#18. Write a program that handles an exception while popping an element from an empty list.
try:
    list1 = ['Python',3.14,2002,True,False,[11,1,1,2,3,50.66,-1],('hello',"World"),{1,1,2,3,5},{'a':'apple',"b":'boy'}]
    index = int(input("Enter index to pop: "))
    list1.pop(index)
    print(list1)
except IndexError:
    print(f"Index Error Occured for {index}\n Enter valid index value")
except ValueError:
    print("Please enter a valid number.")
# Out:
# Enter index to pop:  14
# Index Error Occured for 14
#  Enter valid index value

# %%
#19. Write a program that uses exception handling while performing file write operations.

# %%
#20. Write a program that safely evaluates a mathematical expression entered by the user.
try:
    expre=input("Enter expression :")
    print(eval(expre))
except Exception as e:
    print(e)
# Out:
# Enter expression : 12+5
# 17

# %%
#21.  Write a program that handles exceptions when converting a list of strings into integers.
try:
    list1 = []
    listnum = int(input("How many elements you want in list: "))

    for i in range(listnum):
        enterlist = input("Enter any number: ")
        list1.append(enterlist)

    int_list = []

    for item in list1:
        int_list.append(int(item))

    print("Converted List:", int_list)

except ValueError:
    print(f" values is not a valid integer i.e {item}")
    print("Final Integer List:", int_list)
# Out:
# How many elements you want in list:  4
# Enter any number:  55
# Enter any number:  66
# Enter any number:  po
# Enter any number:  9
#  values is not a valid integer i.e po
# Final Integer List: [55, 66]

# %%
# Out:
# How many elements you want in list:  3
# Enter any number:  14
# Enter any number:  kj
# Enter any number:  6
# ValueError occurred for value: kj
# Final Integer List: [14, 6]

# %%
#22. Write a program that uses try and except to handle errors in list slicing.
try:
    list1 = ['Python',3.14,2002,True,False,[11,1,1,2,3,50.66,-1],('hello',"World"),{1,1,2,3,5},{'a':'apple',"b":'boy'}]
    start = int(input("Enter start index: "))
    end = int(input("Enter end index: "))
    sliced = list1[start:end]
    print("Sliced List:", sliced)

except ValueError:
    print(f"Value Error Occured \n Enter integer value")
except exception as e:
    print(e)
# Out:
# Enter start index:  k
# Value Error Occured
#  Enter integer value

# %%
#23. Write a program that demonstrates how finally executes even when a return statement is used.
try :
    def cap(a,b):
        return a+b

finally:
    print("executed")
cap(6,4)
# Out:
# executed
# 10

# %%
#25 . Write a program that uses exception handling to validate user age input
