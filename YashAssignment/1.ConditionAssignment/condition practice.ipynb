# %%
jun={ 
    "Delhi": ['Redfort','QutubMinar','LotusTemple'],
 "Agra": ["TajMahal"],
 "Jaipur": ["HawaMahal/JalMahal"],
 "Amritsar": ["GoldenTemple,Jalliawalabagh"],
"Madurai":["Meenakshi Temple"],
 "Mysore": ["Mysore palace"],
 "Mumbai" : ["Gateway of India"],
 "Sanchi":["Sanchi Stupa"],
 "Hydrabad": ["Charminar"],
 "Gujarat" : ["Statue of Unity"]}
may = input("City Name")

if may in jun:
     print("Monuments in ",may,"are",)
     print(jun.get(may))
else:
     print("Change Input")
# Out:
# City Name Amritsar
# Monuments in  Amritsar are
# ['GoldenTemple,Jalliawalabagh']

# %%
jun={ 
    "Delhi": ['Redfort','QutubMinar','LotusTemple'],
 "Agra": ["TajMahal"],
 "Jaipur": ["HawaMahal/JalMahal"],
 "Amritsar": ["GoldenTemple,Jalliawalabagh"],
"Madurai":["Meenakshi Temple"],
 "Mysore": ["Mysore palace"],
 "Mumbai" : ["Gateway of India"],
 "Sanchi":["Sanchi Stupa"],
 "Hydrabad": ["Charminar"],
 "Gujarat" : ["Statue of Unity"]}
may = input("City Name")

if may in jun:
     print("Monuments in ",may,"are",)
     print(jun.get(may))
else:
     print("Change Input")
# Out:
# City Name Amritsar
# Monuments in  Amritsar are
# ['GoldenTemple,Jalliawalabagh']

# %%
jun={ 
    "Delhi": ['Redfort','QutubMinar','LotusTemple'],
 "Agra": ["TajMahal"],
 "Jaipur": ["HawaMahal/JalMahal"],
 "Amritsar": ["GoldenTemple,Jalliawalabagh"],
"Madurai":["Meenakshi Temple"],
 "Mysore": ["Mysore palace"],
 "Mumbai" : ["Gateway of India"],
 "Sanchi":["Sanchi Stupa"],
 "Hydrabad": ["Charminar"],
 "Gujarat" : ["Statue of Unity"]}
may = input("City Name")

if may in jun:
     print("Monuments in ",may,"are",)
     print(jun.get(may))
else:
     print("Change Input")
# Out:
# City Name Amritsar
# Monuments in  Amritsar are
# ['GoldenTemple,Jalliawalabagh']

# %%
jun={ 
    "Delhi": ['Redfort','QutubMinar','LotusTemple'],
 "Agra": ["TajMahal"],
 "Jaipur": ["HawaMahal/JalMahal"],
 "Amritsar": ["GoldenTemple,Jalliawalabagh"],
"Madurai":["Meenakshi Temple"],
 "Mysore": ["Mysore palace"],
 "Mumbai" : ["Gateway of India"],
 "Sanchi":["Sanchi Stupa"],
 "Hydrabad": ["Charminar"],
 "Gujarat" : ["Statue of Unity"]}
may = input("City Name")

if may in jun:
     print("Monuments in ",may,"are",)
     print(jun.get(may))
else:
     print("Change Input")
# Out:
# City Name Amritsar
# Monuments in  Amritsar are
# ['GoldenTemple,Jalliawalabagh']

# %%
#discount
a = int(input("Budget:"))
c = 1000-a
if a >= 100:
   if a>2000:
        print("20% dicount applicable")
   elif a>1000 and a<2000:
         print("10% discount applicable")
   elif a<1000 :
       c = 1000-a  
       print(" no discount, add more money min" ,c,"to avail discount")
else    :
    print("Very Poor")
# Out:
# Budget: 560
#  no discount, add more money min 440 to avail discount

# %%
# Company Bonus
y = int(input("Years:"))
s = int(input("Salary:"))

if y>1 :
    if y>10 :
         d = ((110)/100) * s
         print("After Bonus Your Salary: ",d)
    elif y>=6 and y<=10:
         d = ((106)/100) * s
         print("After Bonus Your Salary: ",d)
    elif y<6 :
         d = ((105)/100) * s
         print("After Bomus Your Salary: ",d)
else :
     print("Please enter correct details")
# Out:
# Years: 55
# Salary: 25666
# After Bonus Your Salary:  28232.600000000002

# %%
#Tax of bike
s = int(input("Price OF BIKE:"))
if s>0:
   if s > 100000 :
      d = ((115)/100) * s
      print(f"for bike price of{s}\n new amount to be paid {d}")
   elif s >= 50000 and s < 100000 :
      d = ((110)/100) * s
      print(f"for bike price of{s}\n new amount to be paid {d}")
   elif s<50000 :
      d = ((80)/100) * s
      print(f"for bike price of{s}\n new amount to be paid {d}")
else :
    print("Please enter correct details")
# Out:
# Price OF BIKE: 80000
# for bike price of80000
#  new amount to be paid 88000.0

# %%
#senior citizen age
u = int(input("Age:"))
if u>60:
    print(f"{u}is senoir citizen")
else :
    print(f"{u}You Are Young")
# Out:
# Age: 55
# 55You Are Young

# %%
# positive negative number
z = int(input("Enter Number:"))
if z>0 :
    print(f"{z} is Positive number")
else :
    print(f"{z} is negative number")
# Out:
# Enter Number: 5
# 5 is Positive number

# %%
# 7. Accept the following from the user and calculate the percentage of the class attendence.
# Total number of working days.
# Total number of absent.
# if percentage is less than 75%, then student will not sit the exam.
Total_days = int(input("Enter Working Days"))
Absent_days = int(input("Enter Absent Days"))
Present_days = ((Total_days-Absent_days)/Total_days)* 100

if Total_days > Absent_days:
     if Present_days>=75:
        print(f"Attendance is {Present_days} percent\n He/she can sit for exams")
     else :
         print(f"Attendance is {Present_days} percent\n He/she cannot sit for exams")
else:
   print(f"Data error")
# Out:
# Enter Working Days 80
# Enter Absent Days 90
# Data error

# %%
#8. Calculate letters grades (A,B,C,D,E) based on score ranges (eg.-90-100:A,80-89:B,70-79:C,
#60-69:D,50-59:E)
score = int(input("Enter score"))
if score>=30 and score<=100:
 if score>=90 and score<=100:
        print(f"A Grade for {score} marks")
 elif  score>=80 and score<=89:  
        print(f"B Grade for {score} marks")
 elif score>=70 and score<=79:  
        print(f"C Grade for {score} marks")
 elif score>=60 and score<=69:
        print(f"D Grade for {score} marks")
 elif score>=50 and score<=59:  
        print(f"E Grade for {score} marks")
 else:
     print("failed")
else :
    print("Score Error")
# Out:
# Enter score 999
# Score Error

# %%
# 9. Simulate a traffic light, if the light is "Green", print "Go", If yellow, print "Caution", if red "Stop!"

print("Green-",1)
print("Red-",2)
print("Yellow-",3)
j = int(input("Select and type Number"))
if j == 1:
    print("Go")
elif j == 2:
    print("Stop")
elif j == 3:
    print("Cautious")
else :
    print("Heaven")
# Out:
# Green- 1
# Red- 2
# Yellow- 3
# Select and type Number 2
# Stop

# %%
#user role
log = input(" Please Login")
if log == "admin":
    print("acess granted")
elif log == "editor":
    print("Can edit")
elif log == "viewer":   
    print("Unknown role")
else :
    print("please try agin later")
# Out:
#  Please Login editor
# Can edit

# %%
#Dollar Inr based discount
earn = float(input("Enter amount in Dollars"))
rate = 91.41

if earn>=50 and earn<100:
    tot = rate*earn
    u = ((95)/100)*tot
    print(tot,"INR , After Discount ",u,"INR only")
elif e>=100:
    tot = rate*earn
    u = ((85)/100)*tot
    print(tot,"INR , After Discount ",u,"INR only")    
else :
    print("Check The amount")
# Out:
# Enter amount in Dollars 66
# 6033.0599999999995 INR , After Discount  5731.406999999999 INR only

# %%
# Shape of triangle
h = int(input("Enter no. of sides"))
if h == 3 :
    print("Shape is Triangle")
elif h == 4 :
    print(" Shape is Square/Rectangle")
elif h == 5 :
    print("Shape is Pentagon")
elif h == 6:
    print("Shape is Hexagon")
elif h == 7:
    print("Shape is Heptagon/Septagon")
elif h == 8:
    print("shape is Octagon")
elif h == 9:
    print("Shape is Nonagon")
elif h == 0:
    print("Shape is Circle")
else :
    print("Not Applicable")
# Out:
# Enter no. of sides 8
# shape is Octagon

# %%
#Vowel Consonant identifier
f = input("Enter Character")
if f == "a":
  print("Vowel")
elif f == "e":
  print("Vowel")
elif f == "i":
  print("Vowel")
elif f == "o":
  print("Vowel")
elif f == "u":
  print("Vowel")
else :
    print("consonant")
# Out:
# Enter Character p
# consonant

# %%
#Write a Python program to determine whether a given year is a *leap year* or not.
years = int(input("enter year : "))
if years%4 == 0 and years%100 != 0 :
    print(f"The Given year is {years} :\n 'leap year' ")
elif years%400 == 0 :
    print(f"The Given year is {years} :\n 'leap year' ")  
else :
    print(f"The Given year is {years} :\n ' Not A leap year' ")

# %%
#arithmetic operator
p = float(input(" Enter Value"))
l = float(input(" Enter Value"))

if

# %%
#check whether a number is *positive, **negative, or **zero*.
z = float(input("Enter any Value"))
if z>0:
    print("Positive Number")
elif z == 0:
    print("Zero")
else:
    print("Negative")
# Out:
# Enter any Value 0
# Zero

# %%
#check if  number is *even* or *odd*
e = float(input("Enter any  Value"))
if e%2 == 0:
    print("Even Number")
elif e%2 == 1:
    print("Odd Number")
else:
    print("Error")
# Out:
# Enter any  Value 22.3
# Error

# %%
#*eligible to vote* (age ≥ 18)
y = float(input( "Enter age"))
if y >= 18:
    print("Eligible for voting")
elif y>=0 and y<18  :
    print("Not Eligible For voting")
else :
    print("Error")
# Out:
# Enter age -55
# Error

# %%
# *largest of two numbers*.
x = float(input("Enter Value"))
y = float(input("Enter Value"))
if  x>y :
    print("Greater Value:",x)
elif y>x :
    print("Grweater value:",y)
else :
    print("Equal Value")
# Out:
# Enter Value 55
# Enter Value 69
# Grweater value: 69.0

# %%
#divisible by 5
k = float(input("Enter value"))
if k%5 == 0:
    print("Divisble by 5 :",k)
else :
    print("Not divisible by 5 :",k)
# Out:
# Enter value 55
# Divisble by 5 : 55.0

# %%
#*a multiple of both 3 and 5*.
j = float(input("Enter any Value"))
if j%5 == 0 and j%3 == 0:
    print("yes number is divisble by both [3] and [5]")
else :
    print("Not Divisible{please change input}")
# Out:
# Enter any Value 15
# yes number is divisble by both [3] and [5]

# %%
#*within the range 1–100*.
k = float(input("Enter number"))
if 0 < k and k <= 100:
    print("In range:",k)
else :
    print("Out if range")
# Out:
# Enter number 0
# Out if range

# %%
n = float(input("Enter age"))
if n<=12:
    print("he is Child")
elif n>12 and n<20:
    print("Teenager")
elif n>=20 and n<100 :
    print("Adult")
else :
    print("Please Check the age")
# Out:
# Enter age 222
# Please Check the age

# %%
num1 = float(input(" Enter First Value"))
num2 = float(input(" Enter Second Value"))
num3 = float(input(" Enter Third Value"))
if  num1>num2 and num1>num3:
    print(f" first Value is largest among three : {num1}")
elif num2>num3 and num2>num1:
    print(f" Second Value is largest among three : {num2}") 
else :
    print(f" Third Value is largest among three : {num3}")
# Out:
#  Enter First Value 5
#  Enter Second Value 8
#  Enter Third Value 0
#  Second Value is largest among three : 8.0

# %%
#Write a Python program to check whether a number is *positive and even, **positive and odd, or **negative*.
value = float(input("Enter any number"))
if value.is_integer():
    if value>0 and value%2 == 0:
        print(f"The Given number'{value}' is Positive and Even")
    elif value>0 and value%2 == 1:
         print(f"The Given number'{value}' is Positive and Odd")
    elif value<0 and value%2 == 1:
         print(f"The Given number'{value}' is Negative and Odd")
    else:
         print(f"The Given number'{value}' is Negative-22 and Even")
else:
    
    if value>0:
        print(f"The Given number'{value}' is Positive and Decimal")    
    else:
         print(f"The Given number'{value}' is Negative and Decimal")
# Out:
# Enter any number -0.36
# The Given number'-0.36' is Negative and Decimal

# %%
#Write a Python program to check if a number is *a single-digit, two-digit, or more than two digits*.
num = float(input("Enter any number"))
if num.is_integer():
    if num>0 and num<10 or num<0 and num>-10 :
        print(f" '{num}' is Single digit number")
    elif num>=10 and num<100 or num<=-10 and num>-100:
        print(f" '{num}' is Double digit number")
    elif num<=-100 or num>=100:
        print(f"'{num}' is more then two digits")
else:
    print(f"'{num}' is Decimal Number")
# Out:
# Enter any number 55
#  '55.0' is Double digit number

# %%
#Write a Python program to check whether a character is a *digit, **uppercase letter, **lowercase letter, or **special character*.
word = input("Enter any character")
if word.isdigit():
    print(f"The Given Character '{word}' is Digit")
elif word.isupper():
    print(f"The Given Character '{word}' is Uppercase Letter")
   
elif word.islower():
    print(f"The Given Character '{word}' is Lowercase Letter")
else:
    print(f"The Given Character '{word}' is Special Character")
# Out:
# Enter any character f
# The Given Character 'f' is Lowercase Letter

# %%
#Write a Python program to determine whether a given year is a *century year* (divisible by 100) or not.
years = int(input("enter year : "))
if years%100 == 0 :
    print(f"The Given year is {years} :\n 'Century year' ")
else :
    print(f"The Given year is {years} :\n ' Not A Century year' ")
# Out:
# enter year :  1100
# The Given year is 1100 :
#  'Century year'

# %%
#Write a Python program to check whether the entered password matches the *stored password* or not.
key = input("Please Enter Password")
if key.isalnum() and key == "yash123":
 print(f"Login Sucessfull ")
else :
    print(f"Incorrect password, please try agin later")
# Out:
# Please Enter Password Yash123
# Incorrect password, please try agin later

# %%
##### Write a Python program to find whether a given temperature (°C) is *cold (<20), **moderate (20–30), or **hot (>30)*.

temp = float(input("Enter Temperature"))    
if temp<20 : 
        print(f"the given temperature {temp} is 'cold'")
elif temp>=20 and temp<=30:
         print(f"the given temperature {temp} is 'moderate'")
elif temp>30:
         print(f"the given temperature {temp} is 'hot'")
else :
    print(f"enter the correct value")
# Out:
# Enter Temperature 66
# the given temperature 66.0 is 'hot'

# %%
#Write a Python program to check if the entered number is *a multiple of 2, 3, both, or none*.
num = float(input("Enter any number"))
if num%2 == 0 and num%3 == 0 :
    print(f"Yes, the given number{num} is multiple of both : 2,3")
elif num%2 == 0 :
     print(f"Yes, the given number{num} is multiple of : 2")
elif num%3 == 0 :
      print(f"Yes, the given number{num} is multiple of : 3")
else :
      print(f"No, the given number{num} is not multiple of : 2,3")
# Out:
# Enter any number 55
# No, the given number55.0 is not multiple of : 2,3

# %%
#21. Write a Python program to calculate *discount* based on purchase amount: * > 1000 → 20% discount  * 500–1000 → 10% discount * <500 → No discount

dis = float(input("Enter Purchase amount"))
if dis>1000 :
    dis1 = 80/100*dis 
    only_dis = dis - dis1
    print(f"The purchase amount is {dis}\n Discount  you will get is {"20%"} : that is {only_dis} rupees\n Total amount to be paid is {dis1}  ")
elif dis >=500 and dis<=1000 :
    dis2 = 90/100*dis 
    only_dis1 = dis - dis2
    print(f"The purchase amount is {dis}\n Discount  you will get is 10% 100: that is {only_dis1} rupees\n Total amount to be paid is {dis2}  ")
    
elif dis<500 :
    only_dis2 = 1000 - dis
    only_dis3 = 500 - dis
    print(f"The purchase amount is {dis}\n You will not get any Discount on {dis}\n You need to add minimum amount of {only_dis3}rupees to get (10%) dicount\n OR to get 20% dicount add {only_dis2} rupees ")
else :
    print(f"enter proper amount")
# Out:
# Enter Purchase amount 55
# The purchase amount is 55.0
#  You will not get any Discount on 55.0
#  You need to add minimum amount of 445.0rupees to get (10%) dicount
#  OR to get 20% dicount add 945.0 rupees

# %%
#Write a Python program to check if a given *day number (1–7)* corresponds to *weekday or weekend*.
day = int(input("Enter Day Number"))
if day>=1 and day<=5:
    print(f"The day number {day} is (WEEKDAY)")
elif day == 6 or day == 7 :
    print(f"The day number {day} is (WEEKEND)")
else :
    print(f"Invalid day number {day}")
# Out:
# Enter Day Number 9
# Invalid day number 9

# %%
#Write a Python program to decide the *mode of transport* based on distance:  * <3 km: Walk * 3–15 km: Bike * > 15 km: Car

dist = float(input("Enter Km "))
if dist>0 and dist<3 :
    print(f"Mode of Transport for {dist} is : WALK ")
elif dist>=3 and dist<=15 :
    print(f"Mode of Transport for {dist} is : BIKE ")    
elif dist>15 :
    print(f"Mode of Transport for {dist} is : CAR ")    
else :
    print(f"Enter Proper Distance")
# Out:
# Enter Km  12.6
# Mode of Transport for 12.6 is : BIKE

# %%
#25. Write a Python program to calculate the *electricity bill*:#   ≤100 units → ₹1 per unit
    # 101–200 units → ₹1.5 per unit
    # > 200 units → ₹2 per unit

unit = float(input("Enter NO. of Units"))
if  unit>0 and unit<=100:
    bill = 1*unit
    print(f"Consumption of Units {unit}\n Amount will be Charged per unit is 1₹\n The total Electricity bill is {bill}")
elif unit>100 and unit<=200:
    bill1 = 1.5*unit
    print(f"Consumption of Units {unit}\n Amount will be Charged per unit is 1.5₹\n The total Electricity bill is {bill1}")
elif unit>200:
    bill2 = 2*unit
    print(f"Consumption of Units {unit}\n Amount will be Charged per unit is 2₹\n The total Electricity bill is {bill2}")
else :
    print(f"Enter Correct Units")
# Out:
# Enter NO. of Units 155
# Consumption of Units 155.0
#  Amount will be Charged per unit is 1.5₹
#  The total Electricity bill is 232.5

# %%
#Write a Python program to determine if a student *passed or failed* based on marks in three subjects (passing marks = 40).

sub1 = float((input("Enter Marks of Physics")))
sub2 = float((input("Enter Marks of Chemistry")))
sub3 = float((input("Enter Marks of Maths")))

if 0<=sub1<=100 and 0<=sub2<=100 and 0<=sub3<=100:
    Sum_marks =  sub1 + sub2 +sub3
    total_marks = (sub1 + sub2 +sub3)/3
    if total_marks>=40:
         print(f"The Student is Passed\n Percentage is :{total_marks}% \n Sum Of Subjects :{Sum_marks} ")
    else :
            print(f"The Student is Failed\n Percentage is :{total_marks}% \n Sum Of Subjects :{Sum_marks}")
else :
  print(f"Enter marks between 0 to 100")
# Out:
# Enter Marks of Physics 55
# Enter Marks of Chemistry 98
# Enter Marks of Maths 2
# The Student is Passed
#  Percentage is :51.666666666666664%
#  Sum Of Subjects :155.0

# %%
#arithmetic calculator
num1 = float(input("Enter Number"))
num3 = input("Enter Operator")
num2 = float(input("Enter Number"))



if num3 == "+" :
    outp=num1 + num2
    print(f"The Sum of Two Number is {outp}")
elif num3 == "-" :
    outp1=num1 - num2
    print(f"The Subtraction of Two Number is {outp1}")
elif num3 == "*" :
    outp2=num1 * num2
    print(f"The Multiplication of Two Number is {outp2}")
elif num3 == "/" :
    outp3=num1 / num2
    print(f"The Divison of Two Number is {outp3}")
else :
    print(f"Enter Operator Properly")
# Out:
# Enter Number 99
# Enter Operator /
# Enter Number 3
# The Divison of Two Number is 33.0

# %%
#Write a Python program to check whether a *bank account balance* is *low (<1000), **medium (1000–5000), or **high (>5000)*.
bal = float(input("Enter Bank balance"))
if bal<1000:
    print(f"Your bank balance {bal} is LOW")
elif bal>=1000 and bal<=5000:
    print(f"Your bank balance {bal} is MEDIUM")  
elif bal>5000:
    print(f"Your bank balance {bal} is HIGH")   
else :
    print("Enter Bank balance pproperly")
# Out:
# Enter Bank balance 8596
# Your bank balance 8596.0 is HIGH

# %%
import string

# %%
#Write a Python program to check whether an input string is *empty, **only spaces, or **contains characters*.
printable = '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
whitespace = ' \t\n\r\x0b\x0c'
empty =''
char = input("Enter Anything")
if char in empty:
    print(f"it is Empty:")
elif char in whitespace:
    print(f"It contains only spaces: {char}")
elif char in printable:
    print(f"It Contains Character: {char}")
else :
    print("enter proper value")
# Out:
# Enter Anything p
# It Contains Character: p
