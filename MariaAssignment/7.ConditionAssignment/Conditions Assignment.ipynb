# %% [markdown]
# # Conditions Assignment

# %% [markdown]
# ## Basic level

# %%
# 1) 
num = int(input("Enter any number:"))
if num > 0:
    print("It is a positive number")
elif num ==0:
    print("It is zero")
else:
    print("It is a negative number")
# Out:
# Enter any number: 3
# It is a positive number

# %%
## 2)
num = int(input("Enter any any number"))
if num%2==0:
    print("It is an even number")
else:
    print("It is an odd number")
# Out:
# Enter any any number 3
# It is an odd number

# %%
#3)
age = int(input("Enter your age"))
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")

# %%
#4)
num = int(input("Enter any number"))
if num%5==0:
    print("The number is divisible by 5")
else:
    print("The number is not divisible by 5")

# %%
###### 5)
num = int(input("Enter any number"))
if num%3==0 and num%5==0:
    print("The number divisible by both 3 and 5")
elif num%3==0:
    print("The number is divisible by 3")
elif num%5==0:
    print("The number is divisible by 5")
else:
    print("The no. is neither divisible by 3 nor 5")

# %%
list = ["A","E","I","O","U","a","e","i","o","u"]
a = input("Enter anuy alphabet")
if a in list:
    print("It is an vowel")
else:
    print("It is a consonant")

# %%
age = int(input("Enter your age"))
if age <=12:
    print("You are a child")
elif age>=13 and age<=19:
    print("You are a teenager")
elif age>=20:
    print("You are an adult")
else:
    print("You are a senior citizen")

# %%
num = int(input("Enter any number"))
if num>0 and num<=100:
    print("THe number is within range 1 to 100")
else:
    print("The number is not within range 1 to 100")

# %% [markdown]
# # Intermediate level

# %%
#1)
a = int(input("Enter any number"))
b = int(input("Enter any number"))
c = int(input("Enter any number"))
if a>b>c:
    print(a,"is greater than",b,"and",c)
elif a<b<c:
    print(a,"is less than",b,"and",c)
else:
    print("invalid input")

# %%
num = int(input("Enter any number"))
if num>0 and num%2==0:
    print("The number is positive and an even number")
elif num>0 and num%3==0:
    print("The number is positive and odd number")
elif num<0:
    print("The number is negative")

# %%
num = int(input("Enter any number:"))
if num>=0 and num<10:
    print("It is a single-digit number")
elif num>=10 and num<100:
    print("It is two-digit number")
else:
    print("It is more than two-digit number")

# %%
year = int(input("Enter any year"))
if year%100==0:
    print("It is a century year")
else:
    print("It is not a century year")

# %%
a = "All sides are equal"
b = "Two sides are equal"
c = "All sides are different"
sides = input("State the property of triangle:")
side = sides.capitalize()
if side in a:
    print("It is an equilateral triangle")
elif side in b:
    print("It is an isosceles triangle")
elif side in c:
    print("It is a scalene triangle")
else:
    print("Invalid input")

# %%
num = int(input("Enter any number"))
if num%2==0:
    print("It is a multiple of 2")
elif num%3==0:
    print("It is a multiple of 3")
elif num%2==0 and num%3==0:
    print("It is a multiple of both 2 and 3")
else:
    print("None")

# %%
list =["Delhi","Agra","Jaipur","Amritser","Mysore","Madurai","Mumbai","Sanci","Hyderabad","Gujarat"]
cityName = input("Enter city name:")
cityNames = cityName.capitalize()
if cityNames in list[0]:
    print("Redfort, QutubMinar")
elif cityNames in list[1]:
    print("TajMahal")
elif cityNames in list[2]:
    print("Havamahal")
elif cityNames in list[3]:
    print("Golden Temple")
elif cityNames in list[4]:
    print("Mysore Palace")
elif cityNames in list[5]:
    print("Minakshi Temple")
elif cityNames in list[6]:
    print("Gateway of India")
elif cityNames in list[7]:
    print("Sanchi Stupa")
elif cityNames in list[8]:
    print("Charminar")
elif cityNames in list[9]:
    print("Statue of unity")
else:
    print("Enter only those cities which are mentioned in the list above")

# %%
age = int(input("Enter your age"))
if age>=60:
    print("You are a senior citizen")
else:
    print("You are not a senior citizen ")

# %%
num = int(input("Enter any number"))
if num>0:
    print("It is a positive number")
elif num==0 :
    print("It is zero")
else:
    print("It is a negative number")

# %%
trafic_light = input("Enter the trafic signal:")
light = ["Green","Yellow","Red"]
if trafic_light in light[0]:
    print("Go")
elif trafic_light in light[1]:
    print("Caution")
elif trafic_light in light[2]:
    print("Stop")
else:
    print("Invalid input")

# %%
user_roles = input("Enter the user roles:")
company = ["Admin","Editor","Viewer"]
if user_roles in company[0]:
    print("Access granted")
elif user_roles in company[1]:
    print("Can edit")
elif user_roles in company[2]:
    print("Unknown role")
else:
    print("Invalid input")

# %%
a = input("Enter any alphabet:")
alphabet = ["A","E","I","O","U","a","e","i","o","u"]
if a in alphabet:
    print("It is a vowel")
else:
    print("It is a consonant")
