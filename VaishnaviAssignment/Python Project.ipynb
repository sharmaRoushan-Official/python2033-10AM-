# %% [markdown]
# ### 🧮 Calculator

# %%
num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))

while True:
    print("===== Calculator =====")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "5":
        print("Thank You!!")
        break

    if choice == "1":
        print("Result =", num1 + num2)
        
    elif choice == "2":
        print("Result =", num1 - num2)

    elif choice == "3":
        print("Result =", num1 * num2)

    elif choice == "4":
        print("Result =", num1 / num2)
       
    else:
        print("Invalid Choice!!")
# Out:
# Enter First Number:  25
# Enter Second Number:  22
# ===== Calculator =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice:  35
# Invalid Choice!!
# ===== Calculator =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice:  3
# Result = 550
# ===== Calculator =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice:  2
# Result = 3
# ===== Calculator =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice:  5
# Thank You!!

# %% [markdown]
# ### 📊 Student Marks Manager

# %%
students = []   # List to store student records

def add_student():
    name = input("Enter student name: ")
    total_marks = 100
    marks = int(input("Enter the marks you obtained across the subjects: "))
    pr = marks / total_marks * 100

    if marks>=90 and marks<=100:
        print(f"You got {pr}%\ngrade A+")
    elif marks>=70 and marks<=90:
        print(f"You got {pr}%\ngrade B+")
    elif marks>=50 and marks<=70:
        print(f"You got {pr}%\ngrade C+")
    elif marks>=35 and marks<=50:
        print(f"You got {pr}%\ngrade D+")
    else:
        print("You are not eligible for the next class!!")

    student_record = {
        "Name": "name",
        "Marks": "marks",
        "Percentage": "pr",
        "Grade": "grade"}
    
add_student()
# Out:
# Enter student name:  Mayu
# Enter the marks you obtained across the subjects:  80
# You got 80.0%
# grade B+

# %% [markdown]
# ### 📝 Notes Manager

# %%
file = open("C:\\Users\\Ajit Mohire\\Desktop\\Project.txt","w")

#file.open()
file.write("Programming languages act like translaters.\n")
file.write("Programming \n")
file.close()

#Read file
file = open("C:\\Users\\Ajit Mohire\\Desktop\\Project.txt","r") 
print(file.read())
file.close()

#Append file
file = open("C:\\Users\\Ajit Mohire\\Desktop\\Project.txt","a") 
file.write("Python is a programing language.\n")
file.close()

#delete notes from file
file = open("C:\\Users\\Ajit Mohire\\Desktop\\Project.txt","w")
file.close()
# Out:
# Programming languages act like translaters.
# Programming
