# %%
# Student Marks Manager
from IPython.display import HTML, display

students = {}

def add_student():
    name = input("Enter Student Name: ")
    marks = float(input("Enter Marks: "))
    students[name] = marks
    print("Student Added Successfully.\n")

def show_students():
    if len(students) == 0:
        print("No Student Records Found.\n")
    else:
        print("\nStudent Records")
        for name, marks in students.items():
            print(name, ":", marks)
        print()

def calculate_result():
    if len(students) == 0:
        print("No Data Available.\n")
        return

    marks_list = list(students.values())

    total = sum(marks_list)
    average = total / len(marks_list)
    highest = max(marks_list)
    lowest = min(marks_list)

    print("\n----- Result -----")
    print("Total Marks :", total)
    print("Average Marks :", average)
    print("Highest Marks :", highest)
    print("Lowest Marks :", lowest)
    print()

while True:
    print("===== Student Marks Manager =====")
    print("1. Add Student")
    print("2. Show Students")
    print("3. Calculate Result")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_student()

    elif choice == "2":
        show_students()

    elif choice == "3":
        calculate_result()

    elif choice == "4":
        print("Thank You!")
        break

    else:
        print("sahi karo ise\n")
        display(HTML("""
            <iframe width="700" height="400"
            src="https://www.youtube.com/embed/8pHKxQ_Ogx0?autoplay=1&mute=0"
            frameborder="0"
            allow="autoplay">
            </iframe>
            """))
# Out:
# ===== Student Marks Manager =====
# 1. Add Student
# 2. Show Students
# 3. Calculate Result
# 4. Exit
# Enter your choice:  dhg
# sahi karo ise
#             <iframe width="700" height="400"
#             src="https://www.youtube.com/embed/8pHKxQ_Ogx0?autoplay=1&mute=0"
#             frameborder="0"
#             allow="autoplay">
#             </iframe>
# ===== Student Marks Manager =====
# 1. Add Student
# 2. Show Students
# 3. Calculate Result
# 4. Exit
# Enter your choice:  4
# Thank You!
