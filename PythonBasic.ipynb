# %%
print("Hello world")
# Out:
# Hello world

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello Ajay")
# Out:
# Hello Ajay

# %%
Hello world
# Out:
#   Cell In[5], line 1
#     Hello world
#           ^
# SyntaxError: invalid syntax

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
'Hello world'
# Out:
# 'Hello world'

# %%
'Hello Atharv'
# Out:
# 'Hello Atharv'

# %%
print("Hello Ajay")
print('hello python')
# Out:
# Hello Ajay
# hello python

# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %%
'hello world'
# Out:
# 'hello world'

# %%
# Comment: It cann't be executed by interpreter

# Integer

print(100)
print(999)
print(10000)
print(50000)


# float
print(100.0)
print(999.9)
print(5000.23)
print(1.0)

# Boolean
print(True)
print(False)


# string
print("Hello world")
print('hi,atharv')
print('100')
# Out:
# 100
# 999
# 10000
# 50000
# 100.0
# 999.9
# 5000.23
# 1.0
# True
# False
# Hello world
# hi,atharv
# 100

# %%
10+10
# Out:
# 20

# %%
print("10")
# Out:
# 10

# %%
10+10 # sum
# Out:
# 20

# %%
"10"+"10"  # concatenate
# Out:
# '1010'

# %%
10.23+10.0
# Out:
# 20.23

# %%
"10.23"+"10.0"
# Out:
# '10.2310.0'

# %%
10+10
# Out:
# 20

# %%
"Ajay"*20
# Out:
# 'AjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjayAjay'

# %%
# Comment: It cann't be executed by interpreter

# Integer

print(100)
print(type(100))
print(999)
print(type(999))
print(10000)
print(type(10000))
print(50000)
print(type(50000))


# float
print(100.0)
print(type(100.0))
print(999.9)
print(type(999.9))
print(5000.23)
print(type(5000.23))
print(1.0)
print(type(1.0))

# Boolean
print(True)
print(type(True))
print(False)
print(type(False))


# string
print("Hello world")
print(type("Hello world"))
print('hi,atharv')
print(type('hi,atharv'))
print('100')
print(type('100'))
# Out:
# 100
# <class 'int'>
# 999
# <class 'int'>
# 10000
# <class 'int'>
# 50000
# <class 'int'>
# 100.0
# <class 'float'>
# 999.9
# <class 'float'>
# 5000.23
# <class 'float'>
# 1.0
# <class 'float'>
# True
# <class 'bool'>
# False
# <class 'bool'>
# Hello world
# <class 'str'>
# hi,atharv
# <class 'str'>
# 100
# <class 'str'>

# %%
# type() : It display data type of Python

# %%
# variable and Expression

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = "hello ajay"
print(x)
# Out:
# hello ajay

# %%
x
# Out:
# 'hello ajay'

# %%
x
# Out:
# 'hello ajay'

# %%
x = 100
x
# Out:
# 100

# %%
x
# Out:
# 100

# %%
# with help alphabet 
# alphabet

# %%
true1 = 100

# %%
true1
# Out:
# 100

# %%
= assignment operator

== Comparison operator
# Out:
#   Cell In[81], line 1
#     = assignment operator
#     ^
# SyntaxError: invalid syntax

# %%
# Operators In Python

# 1.Assignemnet operator:- [=]
# 2.Arithematic Operator:- [+,-,*,/,//,%.**]
#     i. Unary Opearator: [++,--]
#         PreIncreament: [++i]
#         PostIncrement:[i++]
#         Pre decrement:[--i]
#         Post Decrement:[i--]
#     ii.Binary operator: [+,-,*,/,//,**,%]

# 3. Membership Operator: [in or not in]
# 4. Identity Operator: [is or is not]
# 5. Comparison Operator: [<,>,<=,>=,!=,==]
# 6.Logical Operator: [AND,OR,NOT]

# %%
num = 6  # number 
print(num)  # display
print(type(num))  # data type of variable num

# convert this number to string, float 

str1 = str(num) 
print(str1)
print(type(str1))


float1 = float(num)
print(float1)
print(type(float1))
# Out:
# 6
# <class 'int'>
# 6
# <class 'str'>
# 6.0
# <class 'float'>

# %%
x = "Hello Ajay"


"6"
# Out:
# '6'

# %%
num=23
print(num)
print(type(num))

str1 = str(num)
print(str1)
print(type(str1))

float1 = float(num)
print(float1)
print(type(float1))
# Out:
# 23
# <class 'int'>
# 23
# <class 'str'>
# 23.0
# <class 'float'>

# %%
float2 = 100.23   #  string:100.23, integer:100
print('Original Value:',float2)
print('Type of data:',type(float2))


# string



# integer
# Out:
# Original Value: 100.23
# Type of data: <class 'float'>

# %%
float2=100.23
print(float2)

print(type(float2))

str1=str(float2)
print(str1)
print(type(str1))

int1=int(float2)
print(int1)
print(type(int1))
# Out:
# 100.23
# <class 'float'>
# 100.23
# <class 'str'>
# 100
# <class 'int'>

# %%
bool1 = True  # string, integer, float
print('Original Value:',bool1)
print("Original Value Data type:",type(bool1))



bool2 = False # string, integer, float
print('Original Value:',bool2)
print("Original Value Data type:",type(bool2))
# Out:
# Original Value: True
# Original Value Data type: <class 'bool'>
# Original Value: False
# Original Value Data type: <class 'bool'>

# %%
bool1 = True  # string, integer, float
print('Original Value:',bool1)
print("Original Value Data type:",type(bool1))


bool2 = False # string, integer, float
print('Original Value:',bool2)
print("Original Value Data type:",type(bool2))
# Out:
# Original Value: True
# Original Value Data type: <class 'bool'>
# Original Value: False
# Original Value Data type: <class 'bool'>

# %%
bool1 = True  # int, string, float
print("Original Value:",bool1)
print("Type of Original Value:",type(bool1))

# integer
boolint = int(bool1) # this value convert boolean to integer
print(boolint)
print(type(boolint))


# string

boolstr = str(bool1)
print(boolstr)
print(type(boolstr))


# float 
boolfloat = float(bool1)
print(boolfloat)
print(type(boolfloat))
# Out:
# Original Value: True
# Type of Original Value: <class 'bool'>
# 1
# <class 'int'>
# True
# <class 'str'>
# 1.0
# <class 'float'>

# %%
### Expression and Variables

x = 56+89+65+78+99
print(x)
# Out:
# 387

# %% [markdown]
# ## 1. how to create Variables in Python
#
#  * In Python, You don't need to declare a type.Just assign the value.

# %%
x = "Hello world"
print(x,type(x))


# Python automatically decided the data type according their value.
# Out:
# Hello world <class 'str'>

# %% [markdown]
# ### 2. Rules for Naming Variables
#
# * You must follow thse rules:
#
# * ✔️ __Allowed__
#
#   * Can contain `letters:(a-z,A-Z)`
#   * Can contain `numbers(0-9)`
#   * Can contain `underscore(_)`

# %%
age = 25
user_name = "Amit"
value1= 100

# %% [markdown]
# ❌ Not Allowd
#
# * Cannot start with a number

# %%
1number = "Wrong"

number1 = "right"
# Out:
#   Cell In[14], line 1
#     1number = "Wrong"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# * Cannot use special characters

# %%
# user-name = "Wrong"  #(hyphen)

# %% [markdown]
# * Cannot use Python keywords

# %%
print = 100
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 print = 100
# ----> 2 print(print)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### Python Keywrods (Avoids These)

# %% [markdown]
# * if
# * else
# * while
# * for
# * class
# * def
# * return
# * True
# * False
# * print
# * len
# * max
# * min
# * True
# * False

# %% [markdown]
# ### multiple variables

# %%
a,b,c = 1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a = 15
b = 20
c = 66
print(a)
print(b)
print(c)
# Out:
# 15
# 20
# 66

# %%
x=y=z = 10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
### Addition (+,Operator): 

x = 15+78+99+68-100.0
print(x,type(x))
# Out:
# 160.0 <class 'float'>

# %%
# Substraction : (-)

x = 47-79
print(x)
print(type(x))
# Out:
# -32
# <class 'int'>

# %%
# Multiplication (*)

a1 = 10
b2 = 13.5

multi= a1*b2
print(multi)
# Out:
# 135.0

# %%
# Normal Division

a1 = 3
b1 = 2

div = a1/b1   # normal division: float value
print(div)
# Out:
# 1.5

# %%
## Floor division

a1 = 3
b1 = 2

div = a1//b1  
print(div)
# Out:
# 1

# %%
# Modulus: % [It return remainder value]

a1 = 3
b1 = 2

div = a1%b1  
print(div)
# Out:
# 1

# %%
a1 = 2
b1 = 2

div = a1%b1  
print(div)
# Out:
# 0

# %%
### Exponent: (Base)²   - (10)²- 10x10=100

# %%
a1 = 10

b1 = 2

expo = a1**b1
print(expo)
# Out:
# 100

# %%
# (10) - 10x10x10 = 1000

a1 = 10

b1 = 3

expo = a1**b1
print(expo)
# Out:
# 1000
